# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
#ler imagem e redimensiona-la
img = Image.open('images/oarsman1.jpeg')
img.thumbnail((256, 256), Image.Resampling.LANCZOS)

# %%
#transformar os pixels em linhas da matrix
i, j = img.size
X = np.asarray(img).reshape((i*j, 3))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x171>

# %%
# aplicar modelo K-means
model = KMeans(n_clusters=5, random_state=10).fit(X)

# %%
# capturar centroides e usar como cores da paleta
colors = model.cluster_centers_.astype('uint8')[np.newaxis]

plt.imshow(colors)
plt.axis('off')
plt.show()
